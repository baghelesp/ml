# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing,tree
import math

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data = pd.read_csv("/content/gdrive/MyDrive/ml_lab/play_tennis.csv")

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %%
col=data.columns.values.tolist()
col
# Out:
# ['day', 'outlook', 'temp', 'humidity', 'wind', 'play']

# %%
for i in col:
  data[i]=label_encoder.fit_transform(data[i])

# %%
data.head()
# Out:
#    day  outlook  temp  humidity  wind  play
# 0    0        2     1         0     1     0
# 1    6        2     1         0     0     0
# 2    7        0     1         0     1     1
# 3    8        1     2         0     1     1
# 4    9        1     0         1     1     1

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

# %%
X=data.iloc[:,0:len(col)-1]
Y=data.iloc[:,len(col)-1:]

# %%
X
# Out:
#     day  outlook  temp  humidity  wind
# 0     0        2     1         0     1
# 1     6        2     1         0     0
# 2     7        0     1         0     1
# 3     8        1     2         0     1
# 4     9        1     0         1     1
# 5    10        1     0         1     0
# 6    11        0     0         1     0
# 7    12        2     2         0     1
# 8    13        2     0         1     1
# 9     1        1     2         1     1
# 10    2        2     2         1     0
# 11    3        0     2         0     0
# 12    4        0     1         1     1
# 13    5        1     2         0     0

# %%
Y
# Out:
#     play
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
# 6      1
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     1
# 13     0

# %%
clf=clf.fit(X,Y)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.3333333333333333, 0.9, 'x[1] <= 0.5\ngini = 0.459\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.2222222222222222, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4444444444444444, 0.7, 'x[3] <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.2222222222222222, 0.5, 'x[0] <= 7.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.1111111111111111, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3333333333333333, 0.3, 'x[0] <= 10.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2222222222222222, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4444444444444444, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.5, 'x[0] <= 9.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5555555555555556, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7777777777777778, 0.3, 'x[0] <= 11.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6666666666666666, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8888888888888888, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]
